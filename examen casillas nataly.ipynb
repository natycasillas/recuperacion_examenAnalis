# %%
import pandas as pd

# %%
import pandas

# %%
pip install couchdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json

# %%
import couchdb

# %%
pelis_df= pd.read_csv("imdb_movies.csv", index_col="names")

# %%
pelis_df
# Out:
#                                               date_x  score
# names
# Creed III                                03/02/2023    73.0  \
# Avatar: The Way of Water                 12/15/2022    78.0
# The Super Mario Bros. Movie              04/05/2023    76.0
# Mummies                                  01/05/2023    70.0
# Supercell                                03/17/2023    61.0
# ...                                              ...    ...
# 20th Century Women                       12/28/2016    73.0
# Delta Force 2: The Colombian Connection  08/24/1990    54.0
# The Russia House                         12/21/1990    61.0
# Darkman II: The Return of Durant         07/11/1995    55.0
# The Swan Princess: A Royal Wedding       07/20/2020    70.0
#
#                                                                                      genre
# names
# Creed III                                                                    Drama, Action  \
# ...

# %%
# Leer el archivo CSV
csv_data = pd.read_csv("imdb_movies.csv")

# %%
# Convertir a JSON con orientación "records"
json_data = csv_data.to_json(orient="records")

# %%
# Guardar el JSON en un archivo
with open("imdb_movies.json", "w") as file:
    file.write(json_data)

# %%
# Conexión a la base de datos CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')
db_name = 'examen'
db = couch[db_name]

# %%
# Cargar y actualizar los documentos en CouchDB
archivo_json = 'imdb_movies.json'
with open(archivo_json) as archivo:
    datos_json = json.load(archivo)
    for documento in datos_json:
        db.save(documento)
